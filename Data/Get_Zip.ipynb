# %%
# Import Dependencies

import geopy
import pandas as pd

# %%
# Make Listings Data from AirBnB a DataFrame

listings_df = pd.read_csv("Columbus_Listings.csv", index_col=0)

# %%
# Show DataFrame

listings_df
# Out:
#                                                                  name  \
# id
# 90676                                Short North - Italianate Cottage
# 543140                             Private queen bedroom 1 - N.Campus
# 591101                The Bellows' Studio Loft  (3rd floor apartment)
# 923248               1 Single Bed in a Shared Coed Dorm at the Hostel
# 927867                                Full Private Room at the Hostel
# ...                                                               ...
# 719459298609982363   Charming 3 Bedroom Home, Steps from Short North!
# 719462438891781706  Private Home away from Home close to Schiller ...
# 719758428460095764      The Top-Floor 1BR Penthouse—Downtown Columbus
# 719760392721789064   *Cameron Room* Cozy, Close to OSU, Downtown, etc
# 719765833016581493  *Clara Room* Spacious, Close to OSU, Downtown,...
#
#                       host_id      host_name  neighbourhood_group  \
# id
# ...

# %%
# Start Geolocator from GeoPY

geolocator = geopy.Nominatim(user_agent="check_1")

# %%
# Function to Retrieve Zip from Latitude and Longitude Coordinates in Listings DataFrame

def get_zip_code(x):
    try:
        location = geolocator.reverse("{}, {}".format(x['latitude'],x['longitude']))
        return location.raw['address']['postcode']
        listings_df['zipcode'] = listings_df.apply(lambda x: get_zip_code(x), axis = 1)
    except KeyError:
       pass

# %%
# Show Listings DataFrame with Zip 

listings_df
# Out:
#                                                                  name  \
# id
# 90676                                Short North - Italianate Cottage
# 543140                             Private queen bedroom 1 - N.Campus
# 591101                The Bellows' Studio Loft  (3rd floor apartment)
# 923248               1 Single Bed in a Shared Coed Dorm at the Hostel
# 927867                                Full Private Room at the Hostel
# ...                                                               ...
# 719459298609982363   Charming 3 Bedroom Home, Steps from Short North!
# 719462438891781706  Private Home away from Home close to Schiller ...
# 719758428460095764      The Top-Floor 1BR Penthouse—Downtown Columbus
# 719760392721789064   *Cameron Room* Cozy, Close to OSU, Downtown, etc
# 719765833016581493  *Clara Room* Spacious, Close to OSU, Downtown,...
#
#                       host_id      host_name  neighbourhood_group  \
# id
# ...

# %%
# Export Dataframe as .csv File 

listings_df.to_csv('Columbus_Listings_with_Zip.csv')
