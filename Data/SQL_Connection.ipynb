# %%
# Create dependencies

import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# Bring in Listings from Get_Zip file

listings_df = pd.read_csv('Columbus_listings_with_Zip.csv')
listings_df
# Out:
#                       id                                               name  \
# 0                  90676                   Short North - Italianate Cottage
# 1                 543140                 Private queen bedroom 1 - N.Campus
# 2                 591101    The Bellows' Studio Loft  (3rd floor apartment)
# 3                 923248   1 Single Bed in a Shared Coed Dorm at the Hostel
# 4                 927867                    Full Private Room at the Hostel
# ...                  ...                                                ...
# 2192  719459298609982363   Charming 3 Bedroom Home, Steps from Short North!
# 2193  719462438891781706  Private Home away from Home close to Schiller ...
# 2194  719758428460095764      The Top-Floor 1BR Penthouse—Downtown Columbus
# 2195  719760392721789064   *Cameron Room* Cozy, Close to OSU, Downtown, etc
# 2196  719765833016581493  *Clara Room* Spacious, Close to OSU, Downtown,...
#
# ...

# %%
# Add the information to send the data to PostgresSQL
    
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/Columbus_AirBnB"
    
engine = create_engine(db_string)
    
listings_df.to_sql(name="listings", con=engine)
# Out:
# 197
