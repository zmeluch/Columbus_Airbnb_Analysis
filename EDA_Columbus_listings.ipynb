# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
listings_df = pd.read_csv("resources/listings.csv")
listings_df.head()
# Out:
#        id                                              name  host_id  \
# 0   90676                  Short North - Italianate Cottage   483306
# 1  543140                Private queen bedroom 1 - N.Campus  2350409
# 2  591101   The Bellows' Studio Loft  (3rd floor apartment)  2889677
# 3  923248  1 Single Bed in a Shared Coed Dorm at the Hostel  4965048
# 4  927867                   Full Private Room at the Hostel  4965048
#
#        host_name  neighbourhood_group          neighbourhood  latitude  \
# 0  Audra & Lacey                  NaN  Near North/University  39.98394
# 1         Edward                  NaN  Near North/University  40.01243
# 2           Gail                  NaN              Near East  39.96086
# 3         Mathew                  NaN  Near North/University  40.01259
# 4         Mathew                  NaN  Near North/University  40.01259
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -83.00321  Entire home/apt    213               1                605
# 1  -83.00986     Private room     29               3                123
# 2  -82.97968     Private room    100               2                272
# 3  -83.00164      Shared room     37               1                286
# 4  -83.00164     Private room     72               1                 63
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2022-09-11               4.54                               3
# 1  2022-08-29               1.00                               3
# 2  2022-09-18               2.21                               1
# 3  2022-09-04               2.45                               9
# 4  2022-06-19               0.57                               9
#
#    availability_365  number_of_reviews_ltm    license
# 0               161                    110  2022-2475
# 1               263                     16  2019-1344
# 2               353                     30  2019-1230
# 3               359                     45  2019-1314
# 4               352                      7  2019-1314

# %%
listings_df.describe()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  2.197000e+03  2.197000e+03                  0.0  2197.000000
# mean   2.354521e+17  1.751620e+08                  NaN    39.988539
# std    3.074351e+17  1.432675e+08                  NaN     0.047325
# min    9.067600e+04  7.876100e+04                  NaN    39.840500
# 25%    3.986819e+07  4.330344e+07                  NaN    39.957060
# 50%    5.203794e+07  1.416151e+08                  NaN    39.981705
# 75%    6.048862e+17  2.635022e+08                  NaN    40.008370
# max    7.197658e+17  4.787276e+08                  NaN    40.153790
#
#          longitude        price  minimum_nights  number_of_reviews  \
# count  2197.000000  2197.000000     2197.000000        2197.000000
# mean    -82.989310   155.325444        6.442421          50.901684
# std       0.049044   123.905519       13.049122          80.326062
# min     -83.175060    19.000000        1.000000           0.000000
# 25%     -83.008930    87.000000        1.000000           4.000000
# 50%     -82.997900   124.000000        2.000000          19.000000
# 75%     -82.971360   182.000000        2.000000          61.000000
# max     -82.775050  1268.000000      300.000000         723.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# count        1940.000000                     2197.000000       2197.000000
# mean            2.781747                       15.794720        197.914429
# std             2.182015                       24.897901        128.962167
# min             0.030000                        1.000000          0.000000
# 25%             1.100000                        1.000000         78.000000
# 50%             2.260000                        4.000000        172.000000
# 75%             3.872500                       23.000000        337.000000
# max            14.000000                      107.000000        365.000000
#
#        number_of_reviews_ltm
# count            2197.000000
# mean               20.807920
# std                24.827134
# min                 0.000000
# 25%                 2.000000
# 50%                12.000000
# 75%                30.000000
# max               175.000000

# %%
profile = ProfileReport(listings_df)

# %%
profile
# Out:
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:438, in ProfileReport._repr_html_(self)
#     436 def _repr_html_(self) -> None:
#     437     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 438     self.to_notebook_iframe()
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:418, in ProfileReport.to_notebook_iframe(self)
#     416 with warnings.catch_warnings():
#     417     warnings.simplefilter("ignore")
# --> 418     display(get_notebook_iframe(self.config, self))
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:388, in ProfileReport.to_html(self)
#     380 def to_html(self) -> str:
#     381     """Generate and return complete template as lengthy string
#     382         for using with frameworks.
#     383
#    (...)
#     386
#     387     """
# --> 388     return self.html
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:205, in ProfileReport.html(self)
#     202 @property
#     203 def html(self) -> str:
#     204     if self._html is None:
# --> 205         self._html = self._render_html()
#     206     return self._html
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:307, in ProfileReport._render_html(self)
#     304 def _render_html(self) -> str:
#     305     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 307     report = self.report
#     309     with tqdm(
#     310         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     311     ) as pbar:
#     312         html = HTMLReport(copy.deepcopy(report)).render(
#     313             nav=self.config.html.navbar_show,
#     314             offline=self.config.html.use_local_assets,
#    (...)
#     322             version=self.description_set["package"]["pandas_profiling_version"],
#     323         )
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:199, in ProfileReport.report(self)
#     196 @property
#     197 def report(self) -> Root:
#     198     if self._report is None:
# --> 199         self._report = get_report_structure(self.config, self.description_set)
#     200     return self._report
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\report\structure\report.py:256, in get_report_structure(config, summary)
#     239 section_items: List[Renderable] = [
#     240     Container(
#     241         get_dataset_items(config, summary, alerts),
#    (...)
#     245     ),
#     246 ]
#     248 if len(summary["variables"]) > 0:
#     249     section_items.append(
#     250         Dropdown(
#     251             name="Variables",
#     252             anchor_id="variables-dropdown",
#     253             id="variables-dropdown",
#     254             items=list(summary["variables"]),
#     255             item=Container(
# --> 256                 render_variables_section(config, summary),
#     257                 sequence_type="accordion",
#     258                 name="Variables",
#     259                 anchor_id="variables",
#     260             ),
#     261         )
#     262     )
#     264 scatter_items = get_scatter_matrix(config, summary["scatter"])
#     265 if len(scatter_items) > 0:
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\report\structure\report.py:103, in render_variables_section(config, dataframe_summary)
#     101 # Per type template variables
#     102 render_map_type = render_map.get(summary["type"], render_map["Unsupported"])
# --> 103 template_variables.update(render_map_type(config, template_variables))
#     105 # Ignore these
#     106 if reject_variables:
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\report\structure\variables\render_categorical.py:370, in render_categorical(config, summary)
#     367     overview_items.append(length_table)
#     369 if characters:
# --> 370     overview_table_char, unitab = render_categorical_unicode(config, summary, varid)
#     371     overview_items.append(overview_table_char)
#     373 overview_items.append(unique_stats)
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\report\structure\variables\render_categorical.py:113, in render_categorical_unicode(config, summary, varid)
#     109 cats = []
#     110 for category_alias_name, category_alias_counts in sorted(
#     111     summary["category_alias_char_counts"].items(), key=lambda x: -len(x[1])
#     112 ):
# --> 113     category_alias_name = category_alias_name.replace("_", " ")
#     114     cats.append(
#     115         FrequencyTable(
#     116             freq_table(
#    (...)
#     124         )
#     125     )
#     127 category_items = [
#     128     category_overview,
#     129     Container(
#    (...)
#     136     ),
#     137 ]
#
# AttributeError: 'NoneType' object has no attribute 'replace'
